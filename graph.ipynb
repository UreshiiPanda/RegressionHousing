# %%
import matplotlib.pyplot as plt
import numpy as np


# RMSLE results as:   Naive, Smart
linreg = [.1524, .1279]
ridge = [.1393, .1276]
polyLin = [.1518, .1274]
polyRidge = [.1401, .1261]


plt.figure(figsize=(8, 6))

X = ['linreg','ridge','poly + linreg','poly + ridge'] 
naive = [.1524, .1393, .1518, .1401] 
smart = [.1279, .1276, .1274, .1261] 
  
X_axis = np.arange(len(X)) 

plt.bar(X_axis - 0.2, naive, 0.4, label = 'Naive') 
plt.bar(X_axis + 0.2, smart, 0.4, label = 'Smart') 
  
plt.xticks(X_axis, X) 
plt.xlabel('Feature/Model Settings')
plt.ylabel("RMSLE") 
plt.title('Comparison of Regression on Housing Price Prediction')
plt.legend() 
plt.show()
